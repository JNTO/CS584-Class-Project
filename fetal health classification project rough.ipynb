# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
pd.set_option('display.max_columns',None) #-This one is used for displaying and visualizing the columns of the dataset.

# %%
data=pd.read_csv("fetal_health.csv")

# %%
#Data Understanding

# %%
data
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
data.shape #here we can see the dimensions of the dataset
# Out:
# (2126, 22)

# %%
data.isna().sum()# here we are checking whether we have missing values
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %%
#here we can see there is none missing values , you have to make sure about it again .Note

# %%
data.isna()
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              False          False           False                 False
# 1              False          False           False                 False
# 2              False          False           False                 False
# 3              False          False           False                 False
# 4              False          False           False                 False
# ...              ...            ...             ...                   ...
# 2121           False          False           False                 False
# 2122           False          False           False                 False
# 2123           False          False           False                 False
# 2124           False          False           False                 False
# 2125           False          False           False                 False
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
import missingno as msmo
msmo.bar(data,color='Red')
# Out:
# <Axes: >

# %%
#Now we are gonna see the datatypes of the dataset 
data.dtypes
# Out:
# baseline value                                            float64
# accelerations                                             float64
# fetal_movement                                            float64
# uterine_contractions                                      float64
# light_decelerations                                       float64
# severe_decelerations                                      float64
# prolongued_decelerations                                  float64
# abnormal_short_term_variability                           float64
# mean_value_of_short_term_variability                      float64
# percentage_of_time_with_abnormal_long_term_variability    float64
# mean_value_of_long_term_variability                       float64
# histogram_width                                           float64
# histogram_min                                             float64
# histogram_max                                             float64
# ...

# %%
# From this, we can conclude the datatypes of the dataset is float

# %%
data.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
#Renaming baseline Value because we can't use that name to call the column. So we are renaming it
data=data.rename(columns={'baseline value':'baseline_value'})

# %%
data.columns
# Out:
# Index(['baseline_value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolongued_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %%
#Getting the value counts for baseline value 
data.baseline_value.value_counts()
# Out:
# 133.0    136
# 130.0    111
# 122.0    109
# 138.0    103
# 125.0     91
# 128.0     85
# 120.0     78
# 142.0     77
# 144.0     77
# 132.0     76
# 136.0     72
# 140.0     70
# 134.0     67
# 135.0     65
# 146.0     62
# 127.0     60
# 137.0     59
# 129.0     57
# 131.0     56
# 143.0     56
# 123.0     56
# 148.0     52
# 121.0     44
# 139.0     39
# 141.0     39
# 126.0     38
# 145.0     37
# 115.0     28
# 150.0     26
# 110.0     21
# 149.0     18
# 119.0     17
# 152.0     17
# 112.0     16
# 147.0     14
# 151.0     14
# 159.0     12
# 114.0     11
# 158.0     10
# 124.0     10
# 118.0      9
# 154.0      8
# 106.0      7
# 116.0      5
# 157.0      4
# 156.0      4
# 117.0      2
# 160.0      1
# Name: baseline_value, dtype: int64

# %%
import matplotlib.pyplot as plt
#Histogram for baseline value 
data.baseline_value.hist()
plt.title('baseline Value');

# %%
#The majority of baseline value ranges between 130 and 140 value.

# %%
#Getting the value counts for accelerations
data.accelerations.value_counts()
# Out:
# 0.000    894
# 0.003    161
# 0.002    160
# 0.001    143
# 0.004    117
# 0.006    112
# 0.005    110
# 0.008    103
# 0.007     91
# 0.009     60
# 0.010     50
# 0.011     36
# 0.012     24
# 0.013     22
# 0.014     20
# 0.015      9
# 0.016      7
# 0.017      4
# 0.018      2
# 0.019      1
# Name: accelerations, dtype: int64

# %%
#Histogram 
data.accelerations.hist()
plt.title('Accelerations');

# %% [markdown]
# #the majority of acceleration value is 0.000

# %%
#Histogram 
data.fetal_movement.hist()
plt.title('fetal_movement');

# %% [markdown]
# #the majority of fetal acceleration value is 0.000

# %%
data.uterine_contractions.hist()
plt.title('uterine_contractions')
# Out:
# Text(0.5, 1.0, 'uterine_contractions')

# %% [markdown]
# From the histogram of uterine contradictions, we can see that the value(0.000,0.003,0.006) has the majority in the histogram when compared with other value.

# %%
data.light_decelerations.hist()
plt.title('light_decelerations')
# Out:
# Text(0.5, 1.0, 'light_decelerations')

# %%
data.severe_decelerations.hist()
plt.title('severe_decelerations')
# Out:
# Text(0.5, 1.0, 'severe_decelerations')

# %%
data.prolongued_decelerations.hist()
plt.title('prolongued_decelerations')
# Out:
# Text(0.5, 1.0, 'prolongued_decelerations')

# %%
data.abnormal_short_term_variability.hist()
plt.title('abnormal_short_term_variability')
# Out:
# Text(0.5, 1.0, 'abnormal_short_term_variability')

# %%
data.mean_value_of_short_term_variability .hist()
plt.title('mean_value_of_short_term_variability ')
# Out:
# Text(0.5, 1.0, 'mean_value_of_short_term_variability ')

# %%
data.percentage_of_time_with_abnormal_long_term_variability .hist()
plt.title('percentage_of_time_with_abnormal_long_term_variability ')
# Out:
# Text(0.5, 1.0, 'percentage_of_time_with_abnormal_long_term_variability ')

# %%
data.mean_value_of_long_term_variability.hist()
plt.title('mean_value_of_long_term_variability')
# Out:
# Text(0.5, 1.0, 'mean_value_of_long_term_variability')

# %%
data. histogram_width.hist()
plt.title('histogram_width')
# Out:
# Text(0.5, 1.0, 'histogram_width')

# %%
data. histogram_min.hist()
plt.title('histogram_min')
# Out:
# Text(0.5, 1.0, 'histogram_min')

# %%
data.histogram_max.hist()
plt.title('histogram_max')
# Out:
# Text(0.5, 1.0, 'histogram_max')

# %%
data.histogram_number_of_peaks.hist()
plt.title('histogram_number_of_peaks')
# Out:
# Text(0.5, 1.0, 'histogram_number_of_peaks')

# %%
data.histogram_number_of_zeroes.hist()
plt.title('histogram_number_of_zeroes')
# Out:
# Text(0.5, 1.0, 'histogram_number_of_zeroes')

# %%
data.histogram_mode.hist()
plt.title('histogram_mode')
# Out:
# Text(0.5, 1.0, 'histogram_mode')

# %%
data.histogram_mean.hist()
plt.title('histogram_mean')
# Out:
# Text(0.5, 1.0, 'histogram_mean')

# %%
data.histogram_mode.hist()
plt.title('Histogram Mode')
# Out:
# Text(0.5, 1.0, 'Histogram Mode')

# %%
data.histogram_median.hist()
plt.title('Histogram Median')
# Out:
# Text(0.5, 1.0, 'Histogram Median')

# %%
data.histogram_variance.hist()
plt.title('Histogram Variance')
# Out:
# Text(0.5, 1.0, 'Histogram Variance')

# %%
data.histogram_tendency.hist()
plt.title('Histogram Tendency')
# Out:
# Text(0.5, 1.0, 'Histogram Tendency')

# %%
fig, axes = plt.subplots(6, 4, figsize=(10, 12))
axes = axes.flatten()
    
# Create a boxplot for each continuous variable
for i, column in enumerate(data.columns):
    sns.boxplot(data=data, x=column, ax=axes[i])
    axes[i].set_title(f"{column}", fontsize=10)
    axes[i].set_xlabel("")  # Remove x-axis title

# Remove empty subplot
for i in range(len(data.columns), len(axes)):
    fig.delaxes(axes[i])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# From the boxplot, we can see that many boxplot exhibits outliers.Moreover, the data was extracted and interepted  by Experts.It is believed that these observation may not be outliers in the actual clinical tests. They could indicate of various factors, such as fetal distree,maternal condition. No action needed to be taken in the outliers.

# %%
#correlation
data.corr()
# Out:
#                                                     baseline_value  \
# baseline_value                                            1.000000
# accelerations                                            -0.080560
# fetal_movement                                           -0.033436
# uterine_contractions                                     -0.146373
# light_decelerations                                      -0.159032
# severe_decelerations                                     -0.053518
# prolongued_decelerations                                 -0.104597
# abnormal_short_term_variability                           0.305570
# mean_value_of_short_term_variability                     -0.279607
# percentage_of_time_with_abnormal_long_term_vari...        0.285630
# mean_value_of_long_term_variability                      -0.032091
# histogram_width                                          -0.147679
# histogram_min                                             0.361619
# ...

# %%
# Set the size of figure to 12 by 10.
plt.figure(figsize=(18,12))
sns.heatmap(data.corr(),annot=True,linewidth=.5)
# Out:
# <Axes: >

# %%
def highly_corr(data):
    
    
    df2 = data.corr()
    
    df1 = pd.DataFrame(df2.unstack(),columns=['corr_value'])
    
    filtered_df = pd.DataFrame(df1[((df1['corr_value'] >= .5) | (df1['corr_value'] <= -.5)) & (df1['corr_value'] !=1.000)])
    
    
    filtered_df.reset_index(inplace=True)
    
    filtered_df.sort_values(by='corr_value',ascending=False,inplace=True)
    filtered_df.drop_duplicates(inplace=True,subset='corr_value',keep='first')
    
    print("Correlation values of highly correlated columns")

    return filtered_df

# %%
highly_corr(data)
# Out:
# Correlation values of highly correlated columns
#                                  level_0  \
# 37                        histogram_mean
# 33                        histogram_mode
# 36                        histogram_mean
# 2                         baseline_value
# 18                       histogram_width
# 34                        histogram_mean
# 31                        histogram_mode
# 25                         histogram_max
# 10  mean_value_of_short_term_variability
# 19                       histogram_width
# 7                    light_decelerations
# 3                    light_decelerations
# 13  mean_value_of_short_term_variability
# 4                    light_decelerations
# 30             histogram_number_of_peaks
# 8               prolongued_decelerations
# 27             histogram_number_of_peaks
# 6                    light_decelerations
# 45                    histogram_variance
# 20                         histogram_min
# 21                         histogram_min
# ...

# %% [markdown]
# From the observation,we can see that the histogram mean , histogram mode, histogram median are highly correlated with each other and it positive correlation
# For negative correlation, we can see that histogram_min and histogram width are highly correlated.

# %%
#Finding the correlation with the predictor and the target value

data.corr()['fetal_health'].sort_values(ascending=False)
# Out:
# fetal_health                                              1.000000
# prolongued_decelerations                                  0.484859
# abnormal_short_term_variability                           0.471191
# percentage_of_time_with_abnormal_long_term_variability    0.426146
# histogram_variance                                        0.206630
# baseline_value                                            0.148151
# severe_decelerations                                      0.131934
# fetal_movement                                            0.088010
# histogram_min                                             0.063175
# light_decelerations                                       0.058870
# histogram_number_of_zeroes                               -0.016682
# histogram_number_of_peaks                                -0.023666
# histogram_max                                            -0.045265
# histogram_width                                          -0.068789
# ...

# %% [markdown]
# prolongued_decelerations                                  0.484859
# abnormal_short_term_variability                           0.471191
# percentage_of_time_with_abnormal_long_term_variability    0.426146
# These are positively correlated with fetal health.
#
# The correlation which are below <0.1 are considered as no correlation

# %%
hist_column = []
kde_column = []

# %%
for i in data.columns:
    if len(data[i].value_counts()) < 10:
        hist_column.append(i)
        print("--------")
        print(i,"-> number of distinct value :",len(data[i].value_counts()))
        print(data[i].value_counts(ascending=False,normalize=True)*100)
        print()
    else:
        kde_column.append(i)
        print(i,"-> number of distinct value :",len(data[i].value_counts()))
        print()
# Out:
# baseline_value -> number of distinct value : 48
#
# accelerations -> number of distinct value : 20
#
# fetal_movement -> number of distinct value : 102
#
# uterine_contractions -> number of distinct value : 16
#
# light_decelerations -> number of distinct value : 16
#
# --------
# severe_decelerations -> number of distinct value : 2
# 0.000    99.670743
# 0.001     0.329257
# Name: severe_decelerations, dtype: float64
#
# --------
# prolongued_decelerations -> number of distinct value : 6
# 0.000    91.627469
# 0.002     3.386642
# 0.001     3.292568
# 0.003     1.128881
# 0.004     0.423330
# 0.005     0.141110
# Name: prolongued_decelerations, dtype: float64
#
# abnormal_short_term_variability -> number of distinct value : 75
#
# mean_value_of_short_term_variability -> number of distinct value : 57
#
# percentage_of_time_with_abnormal_long_term_variability -> number of distinct value : 87
#
# mean_value_of_long_term_variability -> number of distinct value : 249
#
# ...

# %%
data[['severe_decelerations','fetal_health']].value_counts(normalize=True)
# Out:
# severe_decelerations  fetal_health
# 0.000                 1.0             0.777987
#                       2.0             0.138758
#                       3.0             0.079962
# 0.001                 3.0             0.002822
#                       1.0             0.000470
# dtype: float64

# %%
data[['prolongued_decelerations','fetal_health']].value_counts(normalize=True)
# Out:
# prolongued_decelerations  fetal_health
# 0.000                     1.0             0.746002
#                           2.0             0.131703
#                           3.0             0.038570
# 0.001                     1.0             0.025400
# 0.002                     3.0             0.023989
# 0.003                     3.0             0.009407
# 0.002                     1.0             0.006585
# 0.001                     3.0             0.005174
# 0.004                     3.0             0.004233
# 0.002                     2.0             0.003293
# 0.001                     2.0             0.002352
# 0.003                     2.0             0.001411
# 0.005                     3.0             0.001411
# 0.003                     1.0             0.000470
# dtype: float64

# %% [markdown]
# This two features severe decelerations and prolongues decelerations have less distinct values and also have more than 99% values are same.WE can drop these two columns and proceed.

# %%
ax = sns.countplot(data=data, x = 'fetal_health',palette='deep')
ax.bar_label(ax.containers[0])
plt.show()

# %%
#now we are gonna visualize the value  which belongs to which label based on the fetal health column
for i in hist_column:
    plt.figure(figsize=(16,10))
    ax = sns.countplot(data=data, x = i,hue='fetal_health')
    ax.bar_label(ax.containers[0])
    ax.bar_label(ax.containers[1])
    ax.bar_label(ax.containers[2])
    plt.show()
    print()

# %%
for i in kde_column:
    plt.figure(figsize=(16,10))
    ax = sns.countplot(data=data, x = i,hue='fetal_health')
    ax.bar_label(ax.containers[0])
    ax.bar_label(ax.containers[1])
    ax.bar_label(ax.containers[2])
    plt.show()
    print()
